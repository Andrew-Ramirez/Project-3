# %% [markdown]
# ## NN Implementation
# Adapted from https://github.com/fpingham/DeepSteg/blob/master/DeepSteganography.ipynb

# %%
# Imports necessary libraries and modules
from itertools import islice
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.autograd import Variable
from torch import utils
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os 
import pickle
from torchvision import datasets, utils
import torchvision.transforms as transforms
from torchvision.transforms import ToPILImage
from random import shuffle
from IPython.display import Image

# %%
# Directory path
#cwd = 'input'

# Hyper Parameters
num_epochs = 3
batch_size = 2
learning_rate = 0.0001
beta = 1

# Mean and std deviation of imagenet dataset. Source: http://cs231n.stanford.edu/reports/2017/pdfs/101.pdf
#std = [0.229, 0.224, 0.225]
#mean = [0.485, 0.456, 0.406]

# TODO: Define train, validation and models
MODELS_PATH = 'models'
# TRAIN_PATH = cwd+'/train/'
# VALID_PATH = cwd+'/valid/'
TRAIN_PATH = 'coast/train/'
TEST_PATH = 'coast/test/'

#if not os.path.exists(MODELS_PATH): os.mkdir(MODELS_PATH)

# %%
def customized_loss(S_prime, C_prime, S, C, B):
    ''' Calculates loss specified on the paper.'''
    
    loss_cover = torch.nn.functional.mse_loss(C_prime, C)
    loss_secret = torch.nn.functional.mse_loss(S_prime, S)
    loss_all = loss_cover + B * loss_secret
    return loss_all, loss_cover, loss_secret

def denormalize(image, std, mean):
    ''' Denormalizes a tensor of images.'''

    for t in range(3):
        image[t, :, :] = (image[t, :, :] * std[t]) + mean[t]
    return image

def imshow(img, idx, learning_rate, beta):
    '''Prints out an image given in tensor format.'''
    
    #img = denormalize(img, std, mean)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.title('Example '+str(idx)+', lr='+str(learning_rate)+', B='+str(beta))
    plt.show()
    return

def gaussian(tensor, mean=0, stddev=0.1):
    '''Adds random noise to a tensor.'''
    
    noise = torch.nn.init.normal(torch.Tensor(tensor.size()), 0, 0.1)
    return Variable(tensor + noise)

# %%
# Preparation Network (2 conv layers)
class PrepNetwork(nn.Module):
    def __init__(self):
        super(PrepNetwork, self).__init__()
        self.initialP3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialP4 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialP5 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalP3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalP4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalP5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())

    def forward(self, p):
        p1 = self.initialP3(p)
        p2 = self.initialP4(p)
        p3 = self.initialP5(p)
        mid = torch.cat((p1, p2, p3), 1)
        p4 = self.finalP3(mid)
        p5 = self.finalP4(mid)
        p6 = self.finalP5(mid)
        out = torch.cat((p4, p5, p6), 1)
        return out

# Hiding Network (5 conv layers)
class HidingNetwork(nn.Module):
    def __init__(self):
        super(HidingNetwork, self).__init__()
        self.initialH3 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialH4 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialH5 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalH4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalH5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH = nn.Sequential(
            nn.Conv2d(150, 3, kernel_size=1, padding=0))
        
    def forward(self, h):
        h1 = self.initialH3(h)
        h2 = self.initialH4(h)
        h3 = self.initialH5(h)
        mid = torch.cat((h1, h2, h3), 1)
        h4 = self.finalH3(mid)
        h5 = self.finalH4(mid)
        h6 = self.finalH5(mid)
        mid2 = torch.cat((h4, h5, h6), 1)
        out = self.finalH(mid2)
        out_noise = gaussian(out.data, 0, 0.1)
        return out, out_noise

# Reveal Network (2 conv layers)
class RevealNetwork(nn.Module):
    def __init__(self):
        super(RevealNetwork, self).__init__()
        self.initialR3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialR4 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialR5 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalR4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalR5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR = nn.Sequential(
            nn.Conv2d(150, 3, kernel_size=1, padding=0))

    def forward(self, r):
        r1 = self.initialR3(r)
        r2 = self.initialR4(r)
        r3 = self.initialR5(r)
        mid = torch.cat((r1, r2, r3), 1)
        r4 = self.finalR3(mid)
        r5 = self.finalR4(mid)
        r6 = self.finalR5(mid)
        mid2 = torch.cat((r4, r5, r6), 1)
        out = self.finalR(mid2)
        return out

# Join three networks in one module
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.m1 = PrepNetwork()
        self.m2 = HidingNetwork()
        self.m3 = RevealNetwork()

    def forward(self, secret, cover):
        x_1 = self.m1(secret)
        mid = torch.cat((x_1, cover), 1)
        x_2, x_2_noise = self.m2(mid)
        x_3 = self.m3(x_2_noise)
        return x_2, x_3

# %%
net = Net()

# %%
train_loader = torch.utils.data.DataLoader(
        datasets.ImageFolder(
        TRAIN_PATH,
        transforms.Compose([
        transforms.Scale(256),
        transforms.RandomCrop(224),
        transforms.ToTensor(),
        #transforms.Normalize(mean=mean,
        #std=std)
        ])), batch_size=batch_size, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# Creates test set
test_loader = torch.utils.data.DataLoader(
        datasets.ImageFolder(
        TEST_PATH, 
        transforms.Compose([
        transforms.Scale(256),
        transforms.RandomCrop(224),
        transforms.ToTensor(),
        #transforms.Normalize(mean=mean,
        #std=std)
        ])), batch_size=2, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)
# Out:
# C:\Users\Andrew Ramirez\Anaconda3\lib\site-packages\torchvision\transforms\transforms.py:310: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   warnings.warn("The use of the transforms.Scale transform is deprecated, " +

# %%
def train_model(train_loader, beta, learning_rate):
    
    # Save optimizer
    optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    
    loss_history = []
    # Iterate over batches performing forward and backward passes
    for epoch in range(num_epochs):

        # Train mode
        net.train()
        
        train_losses = []
        # Train one epoch
        for idx, train_batch in enumerate(train_loader):

            data, _  = train_batch

            # Saves secret images and secret covers
            train_covers = data[:len(data)//2]
            train_secrets = data[len(data)//2:]
            
            # Creates variable from secret and cover images
            train_secrets = Variable(train_secrets, requires_grad=False)
            train_covers = Variable(train_covers, requires_grad=False)

            # Forward + Backward + Optimize
            optimizer.zero_grad()
            train_hidden, train_output = net(train_secrets, train_covers)

            # Calculate loss and perform backprop
            train_loss, train_loss_cover, train_loss_secret = customized_loss(train_output, train_hidden, train_secrets, train_covers, beta)
            train_loss.backward()
            optimizer.step()
            
            # Saves training loss
            train_losses.append(train_loss.data)
            loss_history.append(train_loss.data)
            
            # Prints mini-batch losses
            print('Training: Batch {0}/{1}. Loss of {2:.4f}, cover loss of {3:.4f}, secret loss of {4:.4f}'.format(idx+1, len(train_loader), train_loss.data, train_loss_cover.data, train_loss_secret.data))
    
        torch.save(net.state_dict(), MODELS_PATH+'Epoch N{}.pkl'.format(epoch+1))
        
        mean_train_loss = np.mean(train_losses)
    
        # Prints epoch average loss
        print ('Epoch [{0}/{1}], Average_loss: {2:.4f}'.format(
                epoch+1, num_epochs, mean_train_loss))
    
    return net, mean_train_loss, loss_history

# %%
net, mean_train_loss, loss_history = train_model(train_loader, beta, learning_rate)
# Out:
# C:\Users\Andrew Ramirez\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Training: Batch 1/144. Loss of 0.5323, cover loss of 0.1401, secret loss of 0.3922
# Training: Batch 2/144. Loss of 0.3927, cover loss of 0.1615, secret loss of 0.2311
# Training: Batch 3/144. Loss of 0.4709, cover loss of 0.2960, secret loss of 0.1749
# Training: Batch 4/144. Loss of 0.9214, cover loss of 0.3446, secret loss of 0.5768
# Training: Batch 5/144. Loss of 0.5493, cover loss of 0.3738, secret loss of 0.1754
# Training: Batch 6/144. Loss of 0.9257, cover loss of 0.6172, secret loss of 0.3086
# Training: Batch 7/144. Loss of 0.6100, cover loss of 0.2328, secret loss of 0.3772
# Training: Batch 8/144. Loss of 0.5051, cover loss of 0.2018, secret loss of 0.3033
# Training: Batch 9/144. Loss of 0.5241, cover loss of 0.1956, secret loss of 0.3285
# Training: Batch 10/144. Loss of 0.5255, cover loss of 0.2690, secret loss of 0.2565
# Training: Batch 11/144. Loss of 0.5332, cover loss of 0.2941, secret loss of 0.2391
# Training: Batch 12/144. Loss of 0.5977, cover loss of 0.1787, secret loss of 0.4190
# Training: Batch 13/144. Loss of 0.4259, cover loss of 0.2196, secret loss of 0.2063
# Training: Batch 14/144. Loss of 0.2843, cover loss of 0.2009, secret loss of 0.0834
# Training: Batch 15/144. Loss of 0.1814, cover loss of 0.1219, secret loss of 0.0595
# Training: Batch 16/144. Loss of 0.1180, cover loss of 0.0484, secret loss of 0.0697
# Training: Batch 17/144. Loss of 0.3474, cover loss of 0.1136, secret loss of 0.2338
# Training: Batch 18/144. Loss of 0.3784, cover loss of 0.0430, secret loss of 0.3354
# Training: Batch 19/144. Loss of 0.5615, cover loss of 0.2893, secret loss of 0.2722
# Training: Batch 20/144. Loss of 0.1486, cover loss of 0.0929, secret loss of 0.0556
# Training: Batch 21/144. Loss of 0.0982, cover loss of 0.0731, secret loss of 0.0251
# Training: Batch 22/144. Loss of 0.1353, cover loss of 0.0645, secret loss of 0.0707
# Training: Batch 23/144. Loss of 0.1601, cover loss of 0.0689, secret loss of 0.0912
# Training: Batch 24/144. Loss of 0.2144, cover loss of 0.0907, secret loss of 0.1237
# Training: Batch 25/144. Loss of 0.2923, cover loss of 0.0695, secret loss of 0.2229
# Training: Batch 26/144. Loss of 0.2712, cover loss of 0.1199, secret loss of 0.1513
# Training: Batch 27/144. Loss of 0.1092, cover loss of 0.0220, secret loss of 0.0872
# Training: Batch 28/144. Loss of 0.2808, cover loss of 0.2142, secret loss of 0.0666
# Training: Batch 29/144. Loss of 0.2350, cover loss of 0.1310, secret loss of 0.1040
# Training: Batch 30/144. Loss of 0.3585, cover loss of 0.2021, secret loss of 0.1564
# Training: Batch 31/144. Loss of 0.2441, cover loss of 0.1554, secret loss of 0.0887
# Training: Batch 32/144. Loss of 0.3510, cover loss of 0.0551, secret loss of 0.2959
# Training: Batch 33/144. Loss of 0.2499, cover loss of 0.0924, secret loss of 0.1575
# Training: Batch 34/144. Loss of 0.1514, cover loss of 0.0241, secret loss of 0.1273
# Training: Batch 35/144. Loss of 0.2115, cover loss of 0.1117, secret loss of 0.0999
# Training: Batch 36/144. Loss of 0.3352, cover loss of 0.0625, secret loss of 0.2727
# Training: Batch 37/144. Loss of 0.2361, cover loss of 0.0467, secret loss of 0.1894
# Training: Batch 38/144. Loss of 0.1664, cover loss of 0.0848, secret loss of 0.0816
# Training: Batch 39/144. Loss of 0.1078, cover loss of 0.0528, secret loss of 0.0550
# Training: Batch 40/144. Loss of 0.1587, cover loss of 0.0170, secret loss of 0.1417
# Training: Batch 41/144. Loss of 0.1403, cover loss of 0.0376, secret loss of 0.1027
# Training: Batch 42/144. Loss of 0.0841, cover loss of 0.0431, secret loss of 0.0410
# Training: Batch 43/144. Loss of 0.0595, cover loss of 0.0385, secret loss of 0.0210
# Training: Batch 44/144. Loss of 0.1759, cover loss of 0.0484, secret loss of 0.1275
# Training: Batch 45/144. Loss of 0.1467, cover loss of 0.0904, secret loss of 0.0563
# Training: Batch 46/144. Loss of 0.1216, cover loss of 0.0728, secret loss of 0.0488
# Training: Batch 47/144. Loss of 0.1062, cover loss of 0.0647, secret loss of 0.0415
# Training: Batch 48/144. Loss of 0.0741, cover loss of 0.0512, secret loss of 0.0229
# Training: Batch 49/144. Loss of 0.0836, cover loss of 0.0446, secret loss of 0.0390
# Training: Batch 50/144. Loss of 0.0948, cover loss of 0.0343, secret loss of 0.0605
# Training: Batch 51/144. Loss of 0.1633, cover loss of 0.0789, secret loss of 0.0845
# Training: Batch 52/144. Loss of 0.0603, cover loss of 0.0368, secret loss of 0.0235
# Training: Batch 53/144. Loss of 0.1033, cover loss of 0.0790, secret loss of 0.0243
# Training: Batch 54/144. Loss of 0.1431, cover loss of 0.0991, secret loss of 0.0440
# Training: Batch 55/144. Loss of 0.0815, cover loss of 0.0406, secret loss of 0.0409
# Training: Batch 56/144. Loss of 0.1231, cover loss of 0.0475, secret loss of 0.0756
# Training: Batch 57/144. Loss of 0.0840, cover loss of 0.0682, secret loss of 0.0157
# Training: Batch 58/144. Loss of 0.0887, cover loss of 0.0587, secret loss of 0.0300
# Training: Batch 59/144. Loss of 0.0715, cover loss of 0.0446, secret loss of 0.0270
# Training: Batch 60/144. Loss of 0.1622, cover loss of 0.0455, secret loss of 0.1168
# Training: Batch 61/144. Loss of 0.0815, cover loss of 0.0473, secret loss of 0.0342
# Training: Batch 62/144. Loss of 0.0891, cover loss of 0.0550, secret loss of 0.0341
# Training: Batch 63/144. Loss of 0.1099, cover loss of 0.0553, secret loss of 0.0546
# Training: Batch 64/144. Loss of 0.0744, cover loss of 0.0185, secret loss of 0.0559
# Training: Batch 65/144. Loss of 0.0652, cover loss of 0.0355, secret loss of 0.0297
# Training: Batch 66/144. Loss of 0.0771, cover loss of 0.0546, secret loss of 0.0225
# Training: Batch 67/144. Loss of 0.1588, cover loss of 0.0730, secret loss of 0.0859
# Training: Batch 68/144. Loss of 0.0841, cover loss of 0.0127, secret loss of 0.0714
# Training: Batch 69/144. Loss of 0.0939, cover loss of 0.0196, secret loss of 0.0743
# Training: Batch 70/144. Loss of 0.1110, cover loss of 0.0423, secret loss of 0.0687
# Training: Batch 71/144. Loss of 0.0994, cover loss of 0.0303, secret loss of 0.0691
# Training: Batch 72/144. Loss of 0.1041, cover loss of 0.0297, secret loss of 0.0743
# Training: Batch 73/144. Loss of 0.0541, cover loss of 0.0217, secret loss of 0.0324
# Training: Batch 74/144. Loss of 0.1072, cover loss of 0.0897, secret loss of 0.0175
# Training: Batch 75/144. Loss of 0.1489, cover loss of 0.0443, secret loss of 0.1047
# Training: Batch 76/144. Loss of 0.0635, cover loss of 0.0361, secret loss of 0.0273
# Training: Batch 77/144. Loss of 0.1082, cover loss of 0.0149, secret loss of 0.0933
# Training: Batch 78/144. Loss of 0.0681, cover loss of 0.0221, secret loss of 0.0460
# Training: Batch 79/144. Loss of 0.0727, cover loss of 0.0177, secret loss of 0.0550
# Training: Batch 80/144. Loss of 0.1185, cover loss of 0.0167, secret loss of 0.1018
# Training: Batch 81/144. Loss of 0.0281, cover loss of 0.0138, secret loss of 0.0143
# Training: Batch 82/144. Loss of 0.0922, cover loss of 0.0103, secret loss of 0.0820
# Training: Batch 83/144. Loss of 0.0687, cover loss of 0.0179, secret loss of 0.0508
# Training: Batch 84/144. Loss of 0.1548, cover loss of 0.0307, secret loss of 0.1241
# Training: Batch 85/144. Loss of 0.1748, cover loss of 0.0627, secret loss of 0.1121
# Training: Batch 86/144. Loss of 0.1026, cover loss of 0.0089, secret loss of 0.0937
# Training: Batch 87/144. Loss of 0.1512, cover loss of 0.0539, secret loss of 0.0973
# Training: Batch 88/144. Loss of 0.1235, cover loss of 0.0232, secret loss of 0.1003
# Training: Batch 89/144. Loss of 0.1202, cover loss of 0.0369, secret loss of 0.0833
# Training: Batch 90/144. Loss of 0.0250, cover loss of 0.0128, secret loss of 0.0122
# Training: Batch 91/144. Loss of 0.1008, cover loss of 0.0226, secret loss of 0.0782
# Training: Batch 92/144. Loss of 0.1046, cover loss of 0.0744, secret loss of 0.0303
# Training: Batch 93/144. Loss of 0.0766, cover loss of 0.0197, secret loss of 0.0569
# Training: Batch 94/144. Loss of 0.1079, cover loss of 0.0157, secret loss of 0.0923
# Training: Batch 95/144. Loss of 0.0897, cover loss of 0.0228, secret loss of 0.0670
# Training: Batch 96/144. Loss of 0.1321, cover loss of 0.0395, secret loss of 0.0926
# Training: Batch 97/144. Loss of 0.1148, cover loss of 0.0092, secret loss of 0.1056
# Training: Batch 98/144. Loss of 0.0505, cover loss of 0.0093, secret loss of 0.0412
# Training: Batch 99/144. Loss of 0.1526, cover loss of 0.0176, secret loss of 0.1350
# Training: Batch 100/144. Loss of 0.1879, cover loss of 0.1053, secret loss of 0.0827
# Training: Batch 101/144. Loss of 0.0705, cover loss of 0.0157, secret loss of 0.0548
# Training: Batch 102/144. Loss of 0.1424, cover loss of 0.0144, secret loss of 0.1279
# Training: Batch 103/144. Loss of 0.0806, cover loss of 0.0101, secret loss of 0.0705
# Training: Batch 104/144. Loss of 0.0635, cover loss of 0.0066, secret loss of 0.0569
# Training: Batch 105/144. Loss of 0.0742, cover loss of 0.0128, secret loss of 0.0614
# Training: Batch 106/144. Loss of 0.1286, cover loss of 0.0107, secret loss of 0.1178
# Training: Batch 107/144. Loss of 0.1479, cover loss of 0.0146, secret loss of 0.1333
# Training: Batch 108/144. Loss of 0.0763, cover loss of 0.0060, secret loss of 0.0702
# Training: Batch 109/144. Loss of 0.1300, cover loss of 0.0294, secret loss of 0.1005
# Training: Batch 110/144. Loss of 0.0510, cover loss of 0.0117, secret loss of 0.0393
# Training: Batch 111/144. Loss of 0.0906, cover loss of 0.0545, secret loss of 0.0360
# Training: Batch 112/144. Loss of 0.0732, cover loss of 0.0067, secret loss of 0.0666
# Training: Batch 113/144. Loss of 0.1587, cover loss of 0.0765, secret loss of 0.0822
# Training: Batch 114/144. Loss of 0.0947, cover loss of 0.0096, secret loss of 0.0850
# Training: Batch 115/144. Loss of 0.1181, cover loss of 0.0168, secret loss of 0.1013
# Training: Batch 116/144. Loss of 0.1102, cover loss of 0.0122, secret loss of 0.0980
# Training: Batch 117/144. Loss of 0.0600, cover loss of 0.0320, secret loss of 0.0280
# Training: Batch 118/144. Loss of 0.1097, cover loss of 0.0089, secret loss of 0.1007
# Training: Batch 119/144. Loss of 0.0569, cover loss of 0.0153, secret loss of 0.0416
# Training: Batch 120/144. Loss of 0.1145, cover loss of 0.0557, secret loss of 0.0587
# Training: Batch 121/144. Loss of 0.1171, cover loss of 0.0333, secret loss of 0.0838
# Training: Batch 122/144. Loss of 0.0857, cover loss of 0.0114, secret loss of 0.0744
# Training: Batch 123/144. Loss of 0.0379, cover loss of 0.0126, secret loss of 0.0252
# Training: Batch 124/144. Loss of 0.1665, cover loss of 0.0257, secret loss of 0.1408
# Training: Batch 125/144. Loss of 0.0441, cover loss of 0.0207, secret loss of 0.0234
# Training: Batch 126/144. Loss of 0.0572, cover loss of 0.0114, secret loss of 0.0457
# Training: Batch 127/144. Loss of 0.0701, cover loss of 0.0122, secret loss of 0.0578
# Training: Batch 128/144. Loss of 0.0688, cover loss of 0.0190, secret loss of 0.0498
# Training: Batch 129/144. Loss of 0.0566, cover loss of 0.0194, secret loss of 0.0372
# Training: Batch 130/144. Loss of 0.2070, cover loss of 0.0088, secret loss of 0.1982
# Training: Batch 131/144. Loss of 0.0743, cover loss of 0.0114, secret loss of 0.0629
# Training: Batch 132/144. Loss of 0.0705, cover loss of 0.0116, secret loss of 0.0589
# Training: Batch 133/144. Loss of 0.0668, cover loss of 0.0149, secret loss of 0.0519
# Training: Batch 134/144. Loss of 0.0678, cover loss of 0.0207, secret loss of 0.0471
# Training: Batch 135/144. Loss of 0.0764, cover loss of 0.0183, secret loss of 0.0581
# Training: Batch 136/144. Loss of 0.0829, cover loss of 0.0570, secret loss of 0.0259
# Training: Batch 137/144. Loss of 0.0604, cover loss of 0.0083, secret loss of 0.0520
# Training: Batch 138/144. Loss of 0.0803, cover loss of 0.0057, secret loss of 0.0745
# Training: Batch 139/144. Loss of 0.0900, cover loss of 0.0232, secret loss of 0.0668
# Training: Batch 140/144. Loss of 0.0850, cover loss of 0.0151, secret loss of 0.0699
# Training: Batch 141/144. Loss of 0.1087, cover loss of 0.0131, secret loss of 0.0956
# Training: Batch 142/144. Loss of 0.0509, cover loss of 0.0040, secret loss of 0.0469
# Training: Batch 143/144. Loss of 0.0549, cover loss of 0.0146, secret loss of 0.0403
# Training: Batch 144/144. Loss of 0.1667, cover loss of 0.1117, secret loss of 0.0550
# Epoch [1/3], Average_loss: 0.1675
# Training: Batch 1/144. Loss of 0.0713, cover loss of 0.0078, secret loss of 0.0635
# Training: Batch 2/144. Loss of 0.0716, cover loss of 0.0155, secret loss of 0.0561
# Training: Batch 3/144. Loss of 0.0707, cover loss of 0.0057, secret loss of 0.0650
# Training: Batch 4/144. Loss of 0.2013, cover loss of 0.0164, secret loss of 0.1850
# Training: Batch 5/144. Loss of 0.1152, cover loss of 0.0748, secret loss of 0.0404
# Training: Batch 6/144. Loss of 0.1389, cover loss of 0.0387, secret loss of 0.1002
# Training: Batch 7/144. Loss of 0.1107, cover loss of 0.0053, secret loss of 0.1054
# Training: Batch 8/144. Loss of 0.0554, cover loss of 0.0084, secret loss of 0.0471
# Training: Batch 9/144. Loss of 0.0568, cover loss of 0.0126, secret loss of 0.0441
# Training: Batch 10/144. Loss of 0.0595, cover loss of 0.0098, secret loss of 0.0497
# Training: Batch 11/144. Loss of 0.1245, cover loss of 0.0050, secret loss of 0.1195
# Training: Batch 12/144. Loss of 0.0903, cover loss of 0.0126, secret loss of 0.0777
# Training: Batch 13/144. Loss of 0.1024, cover loss of 0.0057, secret loss of 0.0967
# Training: Batch 14/144. Loss of 0.0869, cover loss of 0.0098, secret loss of 0.0771
# Training: Batch 15/144. Loss of 0.0628, cover loss of 0.0185, secret loss of 0.0443
# Training: Batch 16/144. Loss of 0.0884, cover loss of 0.0284, secret loss of 0.0599
# Training: Batch 17/144. Loss of 0.0536, cover loss of 0.0082, secret loss of 0.0454
# Training: Batch 18/144. Loss of 0.0994, cover loss of 0.0507, secret loss of 0.0487
# Training: Batch 19/144. Loss of 0.1079, cover loss of 0.0141, secret loss of 0.0938
# Training: Batch 20/144. Loss of 0.0940, cover loss of 0.0116, secret loss of 0.0823
# Training: Batch 21/144. Loss of 0.1995, cover loss of 0.0163, secret loss of 0.1832
# Training: Batch 22/144. Loss of 0.1432, cover loss of 0.0127, secret loss of 0.1304
# Training: Batch 23/144. Loss of 0.1732, cover loss of 0.0027, secret loss of 0.1706
# Training: Batch 24/144. Loss of 0.0463, cover loss of 0.0091, secret loss of 0.0371
# Training: Batch 25/144. Loss of 0.0229, cover loss of 0.0142, secret loss of 0.0087
# Training: Batch 26/144. Loss of 0.0627, cover loss of 0.0136, secret loss of 0.0491
# Training: Batch 27/144. Loss of 0.0976, cover loss of 0.0046, secret loss of 0.0930
# Training: Batch 28/144. Loss of 0.0292, cover loss of 0.0129, secret loss of 0.0163
# Training: Batch 29/144. Loss of 0.1587, cover loss of 0.0054, secret loss of 0.1533
# Training: Batch 30/144. Loss of 0.2177, cover loss of 0.0095, secret loss of 0.2082
# Training: Batch 31/144. Loss of 0.1474, cover loss of 0.0083, secret loss of 0.1391
# Training: Batch 32/144. Loss of 0.2252, cover loss of 0.0158, secret loss of 0.2095
# Training: Batch 33/144. Loss of 0.0452, cover loss of 0.0080, secret loss of 0.0372
# Training: Batch 34/144. Loss of 0.1080, cover loss of 0.0473, secret loss of 0.0606
# Training: Batch 35/144. Loss of 0.1499, cover loss of 0.0047, secret loss of 0.1453
# Training: Batch 36/144. Loss of 0.1222, cover loss of 0.0207, secret loss of 0.1015
# Training: Batch 37/144. Loss of 0.0712, cover loss of 0.0085, secret loss of 0.0627
# Training: Batch 38/144. Loss of 0.1284, cover loss of 0.0259, secret loss of 0.1025
# Training: Batch 39/144. Loss of 0.1398, cover loss of 0.0528, secret loss of 0.0870
# Training: Batch 40/144. Loss of 0.0482, cover loss of 0.0195, secret loss of 0.0287
# Training: Batch 41/144. Loss of 0.1042, cover loss of 0.0072, secret loss of 0.0970
# Training: Batch 42/144. Loss of 0.2053, cover loss of 0.0220, secret loss of 0.1832
# Training: Batch 43/144. Loss of 0.0807, cover loss of 0.0034, secret loss of 0.0773
# Training: Batch 44/144. Loss of 0.1395, cover loss of 0.0263, secret loss of 0.1132
# Training: Batch 45/144. Loss of 0.0463, cover loss of 0.0197, secret loss of 0.0266
# Training: Batch 46/144. Loss of 0.0625, cover loss of 0.0067, secret loss of 0.0558
# Training: Batch 47/144. Loss of 0.0420, cover loss of 0.0287, secret loss of 0.0132
# Training: Batch 48/144. Loss of 0.0715, cover loss of 0.0107, secret loss of 0.0608
# Training: Batch 49/144. Loss of 0.1183, cover loss of 0.0186, secret loss of 0.0997
# Training: Batch 50/144. Loss of 0.0283, cover loss of 0.0075, secret loss of 0.0208
# Training: Batch 51/144. Loss of 0.1063, cover loss of 0.0041, secret loss of 0.1023
# Training: Batch 52/144. Loss of 0.0693, cover loss of 0.0229, secret loss of 0.0464
# Training: Batch 53/144. Loss of 0.0409, cover loss of 0.0062, secret loss of 0.0348
# Training: Batch 54/144. Loss of 0.0661, cover loss of 0.0277, secret loss of 0.0384
# Training: Batch 55/144. Loss of 0.0429, cover loss of 0.0079, secret loss of 0.0350
# Training: Batch 56/144. Loss of 0.0947, cover loss of 0.0087, secret loss of 0.0860
# Training: Batch 57/144. Loss of 0.0730, cover loss of 0.0079, secret loss of 0.0651
# Training: Batch 58/144. Loss of 0.1329, cover loss of 0.0117, secret loss of 0.1212
# Training: Batch 59/144. Loss of 0.0853, cover loss of 0.0194, secret loss of 0.0659
# Training: Batch 60/144. Loss of 0.0469, cover loss of 0.0114, secret loss of 0.0356
# Training: Batch 61/144. Loss of 0.0842, cover loss of 0.0057, secret loss of 0.0785
# Training: Batch 62/144. Loss of 0.0703, cover loss of 0.0097, secret loss of 0.0607
# Training: Batch 63/144. Loss of 0.1497, cover loss of 0.0105, secret loss of 0.1391
# Training: Batch 64/144. Loss of 0.1462, cover loss of 0.0167, secret loss of 0.1295
# Training: Batch 65/144. Loss of 0.0545, cover loss of 0.0091, secret loss of 0.0454
# Training: Batch 66/144. Loss of 0.0508, cover loss of 0.0053, secret loss of 0.0456
# Training: Batch 67/144. Loss of 0.0620, cover loss of 0.0134, secret loss of 0.0487
# Training: Batch 68/144. Loss of 0.0672, cover loss of 0.0074, secret loss of 0.0598
# Training: Batch 69/144. Loss of 0.1052, cover loss of 0.0113, secret loss of 0.0939
# Training: Batch 70/144. Loss of 0.0683, cover loss of 0.0135, secret loss of 0.0548
# Training: Batch 71/144. Loss of 0.0838, cover loss of 0.0089, secret loss of 0.0749
# Training: Batch 72/144. Loss of 0.1145, cover loss of 0.0352, secret loss of 0.0793
# Training: Batch 73/144. Loss of 0.0634, cover loss of 0.0092, secret loss of 0.0542
# Training: Batch 74/144. Loss of 0.0255, cover loss of 0.0145, secret loss of 0.0109
# Training: Batch 75/144. Loss of 0.0664, cover loss of 0.0036, secret loss of 0.0628
# Training: Batch 76/144. Loss of 0.0582, cover loss of 0.0116, secret loss of 0.0466
# Training: Batch 77/144. Loss of 0.0602, cover loss of 0.0067, secret loss of 0.0535
# Training: Batch 78/144. Loss of 0.0313, cover loss of 0.0063, secret loss of 0.0249
# Training: Batch 79/144. Loss of 0.1048, cover loss of 0.0056, secret loss of 0.0991
# Training: Batch 80/144. Loss of 0.0836, cover loss of 0.0081, secret loss of 0.0755
# Training: Batch 81/144. Loss of 0.0887, cover loss of 0.0346, secret loss of 0.0541
# Training: Batch 82/144. Loss of 0.0619, cover loss of 0.0050, secret loss of 0.0569
# Training: Batch 83/144. Loss of 0.0902, cover loss of 0.0092, secret loss of 0.0810
# Training: Batch 84/144. Loss of 0.0982, cover loss of 0.0026, secret loss of 0.0956
# Training: Batch 85/144. Loss of 0.0515, cover loss of 0.0197, secret loss of 0.0318
# Training: Batch 86/144. Loss of 0.0388, cover loss of 0.0061, secret loss of 0.0327
# Training: Batch 87/144. Loss of 0.0752, cover loss of 0.0038, secret loss of 0.0715
# Training: Batch 88/144. Loss of 0.0637, cover loss of 0.0197, secret loss of 0.0440
# Training: Batch 89/144. Loss of 0.0487, cover loss of 0.0106, secret loss of 0.0382
# Training: Batch 90/144. Loss of 0.0639, cover loss of 0.0089, secret loss of 0.0549
# Training: Batch 91/144. Loss of 0.1522, cover loss of 0.0095, secret loss of 0.1427
# Training: Batch 92/144. Loss of 0.1305, cover loss of 0.0082, secret loss of 0.1223
# Training: Batch 93/144. Loss of 0.0843, cover loss of 0.0077, secret loss of 0.0765
# Training: Batch 94/144. Loss of 0.0680, cover loss of 0.0119, secret loss of 0.0561
# Training: Batch 95/144. Loss of 0.0792, cover loss of 0.0045, secret loss of 0.0747
# Training: Batch 96/144. Loss of 0.0971, cover loss of 0.0035, secret loss of 0.0935
# Training: Batch 97/144. Loss of 0.0703, cover loss of 0.0108, secret loss of 0.0594
# Training: Batch 98/144. Loss of 0.0988, cover loss of 0.0127, secret loss of 0.0861
# Training: Batch 99/144. Loss of 0.0826, cover loss of 0.0097, secret loss of 0.0728
# Training: Batch 100/144. Loss of 0.0421, cover loss of 0.0053, secret loss of 0.0369
# Training: Batch 101/144. Loss of 0.0911, cover loss of 0.0292, secret loss of 0.0620
# Training: Batch 102/144. Loss of 0.0512, cover loss of 0.0096, secret loss of 0.0417
# Training: Batch 103/144. Loss of 0.0955, cover loss of 0.0200, secret loss of 0.0755
# Training: Batch 104/144. Loss of 0.1009, cover loss of 0.0049, secret loss of 0.0960
# Training: Batch 105/144. Loss of 0.0619, cover loss of 0.0077, secret loss of 0.0542
# Training: Batch 106/144. Loss of 0.0984, cover loss of 0.0069, secret loss of 0.0915
# Training: Batch 107/144. Loss of 0.0483, cover loss of 0.0033, secret loss of 0.0451
# Training: Batch 108/144. Loss of 0.0431, cover loss of 0.0062, secret loss of 0.0369
# Training: Batch 109/144. Loss of 0.0753, cover loss of 0.0188, secret loss of 0.0564
# Training: Batch 110/144. Loss of 0.0480, cover loss of 0.0022, secret loss of 0.0457
# Training: Batch 111/144. Loss of 0.0733, cover loss of 0.0041, secret loss of 0.0693
# Training: Batch 112/144. Loss of 0.1226, cover loss of 0.0091, secret loss of 0.1134
# Training: Batch 113/144. Loss of 0.1100, cover loss of 0.0026, secret loss of 0.1074
# Training: Batch 114/144. Loss of 0.1245, cover loss of 0.0088, secret loss of 0.1157
# Training: Batch 115/144. Loss of 0.0467, cover loss of 0.0048, secret loss of 0.0419
# Training: Batch 116/144. Loss of 0.0775, cover loss of 0.0060, secret loss of 0.0715
# Training: Batch 117/144. Loss of 0.0456, cover loss of 0.0046, secret loss of 0.0410
# Training: Batch 118/144. Loss of 0.0776, cover loss of 0.0050, secret loss of 0.0727
# Training: Batch 119/144. Loss of 0.0475, cover loss of 0.0046, secret loss of 0.0430
# Training: Batch 120/144. Loss of 0.0874, cover loss of 0.0050, secret loss of 0.0823
# Training: Batch 121/144. Loss of 0.0644, cover loss of 0.0066, secret loss of 0.0578
# Training: Batch 122/144. Loss of 0.0906, cover loss of 0.0220, secret loss of 0.0687
# Training: Batch 123/144. Loss of 0.0820, cover loss of 0.0062, secret loss of 0.0758
# Training: Batch 124/144. Loss of 0.0327, cover loss of 0.0043, secret loss of 0.0283
# Training: Batch 125/144. Loss of 0.0361, cover loss of 0.0033, secret loss of 0.0327
# Training: Batch 126/144. Loss of 0.0298, cover loss of 0.0023, secret loss of 0.0274
# Training: Batch 127/144. Loss of 0.0712, cover loss of 0.0037, secret loss of 0.0675
# Training: Batch 128/144. Loss of 0.0562, cover loss of 0.0017, secret loss of 0.0545
# Training: Batch 129/144. Loss of 0.0419, cover loss of 0.0081, secret loss of 0.0338
# Training: Batch 130/144. Loss of 0.0576, cover loss of 0.0020, secret loss of 0.0556
# Training: Batch 131/144. Loss of 0.1339, cover loss of 0.0059, secret loss of 0.1280
# Training: Batch 132/144. Loss of 0.0489, cover loss of 0.0036, secret loss of 0.0453
# Training: Batch 133/144. Loss of 0.0824, cover loss of 0.0037, secret loss of 0.0787
# Training: Batch 134/144. Loss of 0.0402, cover loss of 0.0055, secret loss of 0.0347
# Training: Batch 135/144. Loss of 0.1484, cover loss of 0.0051, secret loss of 0.1433
# Training: Batch 136/144. Loss of 0.0947, cover loss of 0.0059, secret loss of 0.0888
# Training: Batch 137/144. Loss of 0.0865, cover loss of 0.0042, secret loss of 0.0823
# Training: Batch 138/144. Loss of 0.0300, cover loss of 0.0046, secret loss of 0.0254
# Training: Batch 139/144. Loss of 0.0617, cover loss of 0.0080, secret loss of 0.0537
# Training: Batch 140/144. Loss of 0.0744, cover loss of 0.0048, secret loss of 0.0696
# Training: Batch 141/144. Loss of 0.0463, cover loss of 0.0069, secret loss of 0.0394
# Training: Batch 142/144. Loss of 0.0998, cover loss of 0.0130, secret loss of 0.0869
# Training: Batch 143/144. Loss of 0.0617, cover loss of 0.0055, secret loss of 0.0563
# Training: Batch 144/144. Loss of 0.0676, cover loss of 0.0049, secret loss of 0.0627
# Epoch [2/3], Average_loss: 0.0844
# Training: Batch 1/144. Loss of 0.0439, cover loss of 0.0029, secret loss of 0.0410
# Training: Batch 2/144. Loss of 0.1040, cover loss of 0.0021, secret loss of 0.1019
# Training: Batch 3/144. Loss of 0.0256, cover loss of 0.0031, secret loss of 0.0224
# Training: Batch 4/144. Loss of 0.0612, cover loss of 0.0059, secret loss of 0.0553
# Training: Batch 5/144. Loss of 0.0583, cover loss of 0.0041, secret loss of 0.0542
# Training: Batch 6/144. Loss of 0.0494, cover loss of 0.0063, secret loss of 0.0431
# Training: Batch 7/144. Loss of 0.1913, cover loss of 0.0027, secret loss of 0.1886
# Training: Batch 8/144. Loss of 0.0650, cover loss of 0.0029, secret loss of 0.0621
# Training: Batch 9/144. Loss of 0.0122, cover loss of 0.0049, secret loss of 0.0073
# Training: Batch 10/144. Loss of 0.0406, cover loss of 0.0052, secret loss of 0.0353
# Training: Batch 11/144. Loss of 0.0707, cover loss of 0.0061, secret loss of 0.0645
# Training: Batch 12/144. Loss of 0.0653, cover loss of 0.0089, secret loss of 0.0563
# Training: Batch 13/144. Loss of 0.0836, cover loss of 0.0021, secret loss of 0.0815
# Training: Batch 14/144. Loss of 0.0941, cover loss of 0.0070, secret loss of 0.0871
# Training: Batch 15/144. Loss of 0.0631, cover loss of 0.0038, secret loss of 0.0593
# Training: Batch 16/144. Loss of 0.0544, cover loss of 0.0025, secret loss of 0.0518
# Training: Batch 17/144. Loss of 0.1134, cover loss of 0.0072, secret loss of 0.1062
# Training: Batch 18/144. Loss of 0.0420, cover loss of 0.0064, secret loss of 0.0356
# Training: Batch 19/144. Loss of 0.0690, cover loss of 0.0035, secret loss of 0.0654
# Training: Batch 20/144. Loss of 0.1113, cover loss of 0.0037, secret loss of 0.1076
# Training: Batch 21/144. Loss of 0.0469, cover loss of 0.0025, secret loss of 0.0444
# Training: Batch 22/144. Loss of 0.0577, cover loss of 0.0196, secret loss of 0.0382
# Training: Batch 23/144. Loss of 0.1332, cover loss of 0.0044, secret loss of 0.1288
# Training: Batch 24/144. Loss of 0.0269, cover loss of 0.0041, secret loss of 0.0227
# Training: Batch 25/144. Loss of 0.0885, cover loss of 0.0041, secret loss of 0.0844
# Training: Batch 26/144. Loss of 0.1181, cover loss of 0.0022, secret loss of 0.1159
# Training: Batch 27/144. Loss of 0.1186, cover loss of 0.0031, secret loss of 0.1155
# Training: Batch 28/144. Loss of 0.0343, cover loss of 0.0035, secret loss of 0.0308
# Training: Batch 29/144. Loss of 0.0898, cover loss of 0.0105, secret loss of 0.0793
# Training: Batch 30/144. Loss of 0.0512, cover loss of 0.0073, secret loss of 0.0440
# Training: Batch 31/144. Loss of 0.0902, cover loss of 0.0073, secret loss of 0.0829
# Training: Batch 32/144. Loss of 0.0855, cover loss of 0.0048, secret loss of 0.0807
# Training: Batch 33/144. Loss of 0.0912, cover loss of 0.0117, secret loss of 0.0795
# Training: Batch 34/144. Loss of 0.0218, cover loss of 0.0047, secret loss of 0.0171
# Training: Batch 35/144. Loss of 0.1090, cover loss of 0.0022, secret loss of 0.1068
# Training: Batch 36/144. Loss of 0.1185, cover loss of 0.0067, secret loss of 0.1118
# Training: Batch 37/144. Loss of 0.1250, cover loss of 0.0016, secret loss of 0.1234
# Training: Batch 38/144. Loss of 0.0217, cover loss of 0.0021, secret loss of 0.0196
# Training: Batch 39/144. Loss of 0.0546, cover loss of 0.0060, secret loss of 0.0486
# Training: Batch 40/144. Loss of 0.0654, cover loss of 0.0021, secret loss of 0.0633
# Training: Batch 41/144. Loss of 0.0475, cover loss of 0.0009, secret loss of 0.0466
# Training: Batch 42/144. Loss of 0.0363, cover loss of 0.0057, secret loss of 0.0305
# Training: Batch 43/144. Loss of 0.1139, cover loss of 0.0041, secret loss of 0.1097
# Training: Batch 44/144. Loss of 0.0786, cover loss of 0.0057, secret loss of 0.0729
# Training: Batch 45/144. Loss of 0.0754, cover loss of 0.0008, secret loss of 0.0746
# Training: Batch 46/144. Loss of 0.1431, cover loss of 0.0069, secret loss of 0.1362
# Training: Batch 47/144. Loss of 0.0471, cover loss of 0.0043, secret loss of 0.0427
# Training: Batch 48/144. Loss of 0.0614, cover loss of 0.0041, secret loss of 0.0573
# Training: Batch 49/144. Loss of 0.0351, cover loss of 0.0029, secret loss of 0.0322
# Training: Batch 50/144. Loss of 0.1105, cover loss of 0.0120, secret loss of 0.0985
# Training: Batch 51/144. Loss of 0.0440, cover loss of 0.0026, secret loss of 0.0415
# Training: Batch 52/144. Loss of 0.0426, cover loss of 0.0031, secret loss of 0.0394
# Training: Batch 53/144. Loss of 0.1250, cover loss of 0.0039, secret loss of 0.1211
# Training: Batch 54/144. Loss of 0.0424, cover loss of 0.0016, secret loss of 0.0408
# Training: Batch 55/144. Loss of 0.0936, cover loss of 0.0029, secret loss of 0.0907
# Training: Batch 56/144. Loss of 0.0480, cover loss of 0.0066, secret loss of 0.0415
# Training: Batch 57/144. Loss of 0.0973, cover loss of 0.0044, secret loss of 0.0928
# Training: Batch 58/144. Loss of 0.1237, cover loss of 0.0025, secret loss of 0.1213
# Training: Batch 59/144. Loss of 0.0662, cover loss of 0.0042, secret loss of 0.0620
# Training: Batch 60/144. Loss of 0.0371, cover loss of 0.0061, secret loss of 0.0309
# Training: Batch 61/144. Loss of 0.0813, cover loss of 0.0022, secret loss of 0.0791
# Training: Batch 62/144. Loss of 0.0888, cover loss of 0.0126, secret loss of 0.0762
# Training: Batch 63/144. Loss of 0.0579, cover loss of 0.0051, secret loss of 0.0528
# Training: Batch 64/144. Loss of 0.0467, cover loss of 0.0020, secret loss of 0.0448
# Training: Batch 65/144. Loss of 0.0929, cover loss of 0.0086, secret loss of 0.0843
# Training: Batch 66/144. Loss of 0.0870, cover loss of 0.0038, secret loss of 0.0831
# Training: Batch 67/144. Loss of 0.0589, cover loss of 0.0074, secret loss of 0.0516
# Training: Batch 68/144. Loss of 0.0777, cover loss of 0.0019, secret loss of 0.0757
# Training: Batch 69/144. Loss of 0.0816, cover loss of 0.0054, secret loss of 0.0762
# Training: Batch 70/144. Loss of 0.0392, cover loss of 0.0053, secret loss of 0.0339
# Training: Batch 71/144. Loss of 0.0248, cover loss of 0.0098, secret loss of 0.0149
# Training: Batch 72/144. Loss of 0.0354, cover loss of 0.0039, secret loss of 0.0315
# Training: Batch 73/144. Loss of 0.0850, cover loss of 0.0072, secret loss of 0.0777
# Training: Batch 74/144. Loss of 0.1196, cover loss of 0.0041, secret loss of 0.1156
# Training: Batch 75/144. Loss of 0.0911, cover loss of 0.0062, secret loss of 0.0848
# Training: Batch 76/144. Loss of 0.1394, cover loss of 0.0021, secret loss of 0.1373
# Training: Batch 77/144. Loss of 0.0504, cover loss of 0.0060, secret loss of 0.0444
# Training: Batch 78/144. Loss of 0.0220, cover loss of 0.0009, secret loss of 0.0211
# Training: Batch 79/144. Loss of 0.1359, cover loss of 0.0035, secret loss of 0.1324
# Training: Batch 80/144. Loss of 0.0516, cover loss of 0.0066, secret loss of 0.0450
# Training: Batch 81/144. Loss of 0.0642, cover loss of 0.0082, secret loss of 0.0561
# Training: Batch 82/144. Loss of 0.0464, cover loss of 0.0028, secret loss of 0.0436
# Training: Batch 83/144. Loss of 0.0641, cover loss of 0.0011, secret loss of 0.0630
# Training: Batch 84/144. Loss of 0.0690, cover loss of 0.0075, secret loss of 0.0614
# Training: Batch 85/144. Loss of 0.0808, cover loss of 0.0028, secret loss of 0.0780
# Training: Batch 86/144. Loss of 0.0724, cover loss of 0.0027, secret loss of 0.0698
# Training: Batch 87/144. Loss of 0.0860, cover loss of 0.0042, secret loss of 0.0818
# Training: Batch 88/144. Loss of 0.1220, cover loss of 0.0060, secret loss of 0.1159
# Training: Batch 89/144. Loss of 0.0981, cover loss of 0.0025, secret loss of 0.0956
# Training: Batch 90/144. Loss of 0.0398, cover loss of 0.0040, secret loss of 0.0358
# Training: Batch 91/144. Loss of 0.0316, cover loss of 0.0045, secret loss of 0.0270
# Training: Batch 92/144. Loss of 0.0663, cover loss of 0.0049, secret loss of 0.0615
# Training: Batch 93/144. Loss of 0.0361, cover loss of 0.0026, secret loss of 0.0335
# Training: Batch 94/144. Loss of 0.0965, cover loss of 0.0013, secret loss of 0.0952
# Training: Batch 95/144. Loss of 0.0735, cover loss of 0.0055, secret loss of 0.0680
# Training: Batch 96/144. Loss of 0.0534, cover loss of 0.0011, secret loss of 0.0523
# Training: Batch 97/144. Loss of 0.0426, cover loss of 0.0021, secret loss of 0.0405
# Training: Batch 98/144. Loss of 0.0559, cover loss of 0.0014, secret loss of 0.0545
# Training: Batch 99/144. Loss of 0.0807, cover loss of 0.0018, secret loss of 0.0789
# Training: Batch 100/144. Loss of 0.1002, cover loss of 0.0014, secret loss of 0.0988
# Training: Batch 101/144. Loss of 0.0674, cover loss of 0.0028, secret loss of 0.0646
# Training: Batch 102/144. Loss of 0.1221, cover loss of 0.0008, secret loss of 0.1213
# Training: Batch 103/144. Loss of 0.1299, cover loss of 0.0138, secret loss of 0.1161
# Training: Batch 104/144. Loss of 0.1372, cover loss of 0.0019, secret loss of 0.1353
# Training: Batch 105/144. Loss of 0.0579, cover loss of 0.0024, secret loss of 0.0556
# Training: Batch 106/144. Loss of 0.0350, cover loss of 0.0027, secret loss of 0.0323
# Training: Batch 107/144. Loss of 0.0665, cover loss of 0.0045, secret loss of 0.0620
# Training: Batch 108/144. Loss of 0.0752, cover loss of 0.0029, secret loss of 0.0724
# Training: Batch 109/144. Loss of 0.0364, cover loss of 0.0046, secret loss of 0.0319
# Training: Batch 110/144. Loss of 0.0537, cover loss of 0.0092, secret loss of 0.0444
# Training: Batch 111/144. Loss of 0.0380, cover loss of 0.0020, secret loss of 0.0360
# Training: Batch 112/144. Loss of 0.0527, cover loss of 0.0075, secret loss of 0.0452
# Training: Batch 113/144. Loss of 0.0406, cover loss of 0.0032, secret loss of 0.0374
# Training: Batch 114/144. Loss of 0.1236, cover loss of 0.0099, secret loss of 0.1137
# Training: Batch 115/144. Loss of 0.0752, cover loss of 0.0031, secret loss of 0.0721
# Training: Batch 116/144. Loss of 0.1100, cover loss of 0.0052, secret loss of 0.1048
# Training: Batch 117/144. Loss of 0.0675, cover loss of 0.0029, secret loss of 0.0646
# Training: Batch 118/144. Loss of 0.0406, cover loss of 0.0010, secret loss of 0.0396
# Training: Batch 119/144. Loss of 0.1209, cover loss of 0.0026, secret loss of 0.1183
# Training: Batch 120/144. Loss of 0.0497, cover loss of 0.0059, secret loss of 0.0438
# Training: Batch 121/144. Loss of 0.0500, cover loss of 0.0029, secret loss of 0.0471
# Training: Batch 122/144. Loss of 0.0546, cover loss of 0.0104, secret loss of 0.0442
# Training: Batch 123/144. Loss of 0.0715, cover loss of 0.0014, secret loss of 0.0700
# Training: Batch 124/144. Loss of 0.0817, cover loss of 0.0038, secret loss of 0.0779
# Training: Batch 125/144. Loss of 0.0310, cover loss of 0.0039, secret loss of 0.0271
# Training: Batch 126/144. Loss of 0.0172, cover loss of 0.0016, secret loss of 0.0156
# Training: Batch 127/144. Loss of 0.0944, cover loss of 0.0026, secret loss of 0.0919
# Training: Batch 128/144. Loss of 0.1434, cover loss of 0.0028, secret loss of 0.1406
# Training: Batch 129/144. Loss of 0.0336, cover loss of 0.0027, secret loss of 0.0309
# Training: Batch 130/144. Loss of 0.1011, cover loss of 0.0022, secret loss of 0.0989
# Training: Batch 131/144. Loss of 0.0580, cover loss of 0.0011, secret loss of 0.0569
# Training: Batch 132/144. Loss of 0.0353, cover loss of 0.0017, secret loss of 0.0336
# Training: Batch 133/144. Loss of 0.0307, cover loss of 0.0026, secret loss of 0.0281
# Training: Batch 134/144. Loss of 0.0525, cover loss of 0.0031, secret loss of 0.0494
# Training: Batch 135/144. Loss of 0.0499, cover loss of 0.0037, secret loss of 0.0462
# Training: Batch 136/144. Loss of 0.0742, cover loss of 0.0017, secret loss of 0.0726
# Training: Batch 137/144. Loss of 0.1293, cover loss of 0.0066, secret loss of 0.1227
# Training: Batch 138/144. Loss of 0.0783, cover loss of 0.0055, secret loss of 0.0728
# Training: Batch 139/144. Loss of 0.0864, cover loss of 0.0035, secret loss of 0.0829
# Training: Batch 140/144. Loss of 0.1430, cover loss of 0.0023, secret loss of 0.1406
# Training: Batch 141/144. Loss of 0.0537, cover loss of 0.0065, secret loss of 0.0472
# Training: Batch 142/144. Loss of 0.0538, cover loss of 0.0023, secret loss of 0.0515
# Training: Batch 143/144. Loss of 0.0465, cover loss of 0.0018, secret loss of 0.0448
# Training: Batch 144/144. Loss of 0.1073, cover loss of 0.0012, secret loss of 0.1061
# Epoch [3/3], Average_loss: 0.0726

# %%
# Plot loss through epochs
plt.plot(loss_history)
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Batch')
plt.show()

# %%
# net.load_state_dict(torch.load(MODELS_PATH+'Epoch N4.pkl'))

# Switch to evaluate mode
net.eval()

test_losses = []
# Show images
for idx, test_batch in enumerate(test_loader):
     # Saves images
    data, _ = test_batch

    # Saves secret images and secret covers
    test_secret = data[:len(data)//2]
    test_cover = data[len(data)//2:]

    # Creates variable from secret and cover images
    test_secret = Variable(test_secret, volatile=True)
    test_cover = Variable(test_cover, volatile=True)

    # Compute output
    test_hidden, test_output = net(test_secret, test_cover)
    
    # Calculate loss
    test_loss, loss_cover, loss_secret = customized_loss(test_output, test_hidden, test_secret, test_cover, beta)
    
#     diff_S, diff_C = np.abs(np.array(test_output.data[0]) - np.array(test_secret.data[0])), np.abs(np.array(test_hidden.data[0]) - np.array(test_cover.data[0]))
    
#     print (diff_S, diff_C)
    
    if idx in [1,2,3,4]:
        print ('Total loss: {:.2f} \nLoss on secret: {:.2f} \nLoss on cover: {:.2f}'.format(test_loss.data, loss_secret.data, loss_cover.data))

        # Creates img tensor
        imgs = [test_secret.data, test_output.data, test_cover.data, test_hidden.data]
        imgs_tsor = torch.cat(imgs, 0)

        # Prints Images
        imshow(utils.make_grid(imgs_tsor), idx+1, learning_rate=learning_rate, beta=beta)
        
    test_losses.append(test_loss.data)
        
mean_test_loss = np.mean(test_losses)

print ('Average loss on test set: {:.2f}'.format(mean_test_loss))
# Out:
# C:\Users\Andrew Ramirez\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# C:\Users\Andrew Ramirez\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# C:\Users\Andrew Ramirez\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Total loss: 0.07
# Loss on secret: 0.07
# Loss on cover: 0.00
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.05
# Loss on secret: 0.04
# Loss on cover: 0.00
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.04
# Loss on secret: 0.04
# Loss on cover: 0.00
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.05
# Loss on secret: 0.05
# Loss on cover: 0.00
# Average loss on test set: 0.08

# %% [markdown]
# ### Testing with Kodak Set

# %%
# net.load_state_dict(torch.load(MODELS_PATH+'Epoch N4.pkl'))
kodak_path = 'kodakSet/temp'
kodak_test = torch.utils.data.DataLoader(
        datasets.ImageFolder(
        kodak_path, 
        transforms.Compose([
        transforms.Scale(256),
        transforms.RandomCrop(224),
        transforms.ToTensor(),
        #transforms.Normalize(mean=mean,
        #std=std)
        ])), batch_size=2, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)
# Switch to evaluate mode
net.eval()

test_losses = []
# Show images
for idx, test_batch in enumerate(kodak_test):
     # Saves images
    data, _ = test_batch

    # Saves secret images and secret covers
    test_secret = data[:len(data)//2]
    test_cover = data[len(data)//2:]

    # Creates variable from secret and cover images
    test_secret = Variable(test_secret, volatile=True)
    test_cover = Variable(test_cover, volatile=True)

    # Compute output
    test_hidden, test_output = net(test_secret, test_cover)
    
    # Calculate loss
    test_loss, loss_cover, loss_secret = customized_loss(test_output, test_hidden, test_secret, test_cover, beta)
    
#     diff_S, diff_C = np.abs(np.array(test_output.data[0]) - np.array(test_secret.data[0])), np.abs(np.array(test_hidden.data[0]) - np.array(test_cover.data[0]))
    
#     print (diff_S, diff_C)
    
    if idx in [1,2,3,4]:
        print ('Total loss: {:.2f} \nLoss on secret: {:.2f} \nLoss on cover: {:.2f}'.format(test_loss.data, loss_secret.data, loss_cover.data))

        # Creates img tensor
        imgs = [test_secret.data, test_output.data, test_cover.data, test_hidden.data]
        imgs_tsor = torch.cat(imgs, 0)

        # Prints Images
        imshow(utils.make_grid(imgs_tsor), idx+1, learning_rate=learning_rate, beta=beta)
        
    test_losses.append(test_loss.data)
        
mean_test_loss = np.mean(test_losses)

print ('Average loss on test set: {:.2f}'.format(mean_test_loss))
# Out:
# C:\Users\Andrew Ramirez\Anaconda3\lib\site-packages\ipykernel_launcher.py:28: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# C:\Users\Andrew Ramirez\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# C:\Users\Andrew Ramirez\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Total loss: 0.22
# Loss on secret: 0.22
# Loss on cover: 0.01
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.06
# Loss on secret: 0.05
# Loss on cover: 0.01
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.06
# Loss on secret: 0.05
# Loss on cover: 0.00
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.03
# Loss on secret: 0.03
# Loss on cover: 0.00
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Average loss on test set: 0.07
